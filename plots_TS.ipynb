# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_n = pd.read_csv("our_predictions/prediction_006950_n.txt")
df_m = pd.read_csv("our_predictions/prediction_006950_m.txt")
df_x = pd.read_csv("our_predictions/prediction_006950_x.txt")

# %%
df_n
# Out:
#                                             img_path  inference_time  \
# 0  /work/vita/nmuenger_trinca/annotations/images/...       18.365383
#
#    class_id class_name        x_box       y_box      w_box      h_box
# 0     154.0    F50.png  1122.455566  241.334671  56.266235  52.424286

# %%
plt.bar(["nano", "medium", "x-tra large"],[df_n.iloc[0]["inference_time"],df_m.iloc[0]["inference_time"],df_x.iloc[0]["inference_time"]])
plt.xlabel("Model name")
plt.ylabel("Inference time [ms]")
plt.title("Comparison of the models' inference time on one image");
plt.savefig("our_predictions/time_vs_model.png")

# %%
plt.bar(["nano", "medium", "x-tra large"],[9602, 51786,133873])
plt.xlabel("Model name")
plt.ylabel("Model size [Ko]")
plt.title("Comparison of the models' size");
plt.savefig("our_predictions/size_vs_model.png")
